# %%
# Dylan H.
# This notebook collects & sorts still images from the Global Irminger Sea Array
# for the iceflow detection model

# %% [markdown]
# # Getting Irminger Data
#
# Irminger data can be found here:
# [R00007](https://rawdata.oceanobservatories.org/files/GI01SUMO/R00007/instruments/dcl13/vics/imageData/)
# [R00009](https://rawdata.oceanobservatories.org/files/GI01SUMO/R00009/instruments/dcl13/vics/imageData/)
# [R00010](https://rawdata.oceanobservatories.org/files/GI01SUMO/R00010/cg_data/dcl13/vics/vics_host_downloaded/imageData/)
# [R00005](https://rawdata.oceanobservatories.org/files/GI01SUMO/R00005/cg_data/dcl13/vics-hourly/)
# [R00006](https://rawdata.oceanobservatories.org/files/GI01SUMO/R00006/cg_data/dcl13/vics/imageData/)

# %%
import os
import shutil
from pathlib import Path

# %%
# make dir for raw data if it doesn't exist
os.makedirs("raw_data", exist_ok=True)

# sources
sources = ["https://rawdata.oceanobservatories.org/files/GI01SUMO/R00007/instruments/dcl13/vics/imageData/",
           "https://rawdata.oceanobservatories.org/files/GI01SUMO/R00009/instruments/dcl13/vics/imageData/",
           "https://rawdata.oceanobservatories.org/files/GI01SUMO/R00010/cg_data/dcl13/vics/vics_host_downloaded/imageData/",
           "https://rawdata.oceanobservatories.org/files/GI01SUMO/R00005/cg_data/dcl13/vics-hourly/",
           "https://rawdata.oceanobservatories.org/files/GI01SUMO/R00006/cg_data/dcl13/vics/imageData/"
          ]
# pull raw data
for url in sources:
    # !wget -r -np -e robots=off -P raw_data/ {url} -q --show-progress
# Out:
# rawdata.oceanobserv     [ <=>                ]  24.34K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.34K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.34K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.34K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.34K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]   2.25K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  27.08K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  20.40K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  20.40K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  10.85K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  20.40K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]   4.16K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  11.80K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  23.26K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  17.53K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]   8.94K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.34K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.34K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.34K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.34K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]   2.25K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]   2.25K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]   2.25K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]   2.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 197.55K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 103.41K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 149.15K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 182.01K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 198.59K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>]  99.29K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  22.31K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.66K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 159.35K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 267.00K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 127.08K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 162.16K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 172.93K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 123.74K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 158.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 258.00K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 115.79K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 125.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 170.29K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 128.66K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 154.98K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 258.63K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 125.19K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 112.36K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 177.19K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 125.61K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 154.79K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 257.66K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 116.79K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 107.87K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 174.34K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 125.40K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 155.89K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 257.03K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 112.51K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 108.40K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 170.62K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 229.17K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 199.06K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 265.56K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 213.50K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 223.54K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 218.20K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 142.59K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 196.25K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 193.61K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 128.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 126.94K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 207.56K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 135.63K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 269.44K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 191.14K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 114.54K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.18K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 228.18K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 140.17K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 267.03K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 177.51K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 115.88K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 125.15K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 202.13K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 101.94K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 271.65K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 204.76K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 104.58K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 132.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 200.61K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 109.59K  --.-KB/s    in 0.005s
# rawdata.oceanobserv 100%[===================>] 218.67K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 209.19K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 110.95K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 118.35K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 211.96K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 158.14K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 201.72K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 181.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 128.03K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 147.53K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 195.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 117.43K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 209.63K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 207.14K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 100.19K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.42K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 195.72K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 119.71K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 187.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 179.66K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 103.50K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.27K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 182.07K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 152.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 202.87K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 188.85K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 118.14K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 153.91K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 188.62K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.07K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 187.89K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 175.66K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 101.23K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 124.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 196.19K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 124.97K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 184.53K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 195.90K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 101.39K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 125.14K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 189.82K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 131.30K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 185.03K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 190.21K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>]  99.48K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 124.55K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 219.74K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 128.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 182.11K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 176.83K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 105.43K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 122.04K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 190.30K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 125.56K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 205.02K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 181.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 112.56K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 125.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 223.23K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 134.78K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 202.50K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 194.52K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 112.23K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.03K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 193.94K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 190.63K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 231.20K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 259.53K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 188.11K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 192.38K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 238.12K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  21.35K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 203.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 211.57K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 277.10K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 140.12K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 206.14K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 210.42K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 202.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 212.98K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 278.29K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 138.29K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 207.13K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 208.30K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 202.26K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 311.07K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 298.18K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 143.95K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 207.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 213.41K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 200.74K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 258.26K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 310.32K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 209.36K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 210.05K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 239.89K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 194.53K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 245.83K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 313.35K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 171.44K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 206.70K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 233.68K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 199.64K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 226.21K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 285.00K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 154.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 207.50K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 218.27K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 191.26K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 242.35K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 288.37K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 208.67K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 198.63K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 229.70K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 150.46K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 214.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 212.01K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 118.98K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 128.34K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 227.10K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 123.74K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 219.09K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 240.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 116.92K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 112.51K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 248.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.32K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 201.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 185.55K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 108.53K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 132.65K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 205.92K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 122.74K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 219.85K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 208.37K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 114.17K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.07K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 215.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 126.49K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 222.59K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 200.91K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 106.20K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.43K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 198.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 165.11K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 238.04K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 211.13K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 119.82K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 139.74K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 214.12K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 145.90K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 190.60K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 194.60K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.15K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 128.67K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 241.27K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 166.29K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 284.81K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 253.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 157.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 139.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 316.69K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 168.08K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 252.81K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 211.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 116.42K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 145.81K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 242.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 154.21K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 243.69K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 218.72K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 152.11K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 142.45K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 315.77K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 145.17K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 280.27K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 218.66K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 151.66K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 143.32K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 241.89K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 155.26K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 262.10K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 236.82K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 178.79K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 149.65K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 281.04K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 153.78K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 247.23K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 214.71K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 143.77K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 136.90K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 226.44K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 142.24K  --.-KB/s    in 0.004s
# rawdata.oceanobserv 100%[===================>] 227.95K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 235.30K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 145.89K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 136.57K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 251.84K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  27.08K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  27.08K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  27.08K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  27.08K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 145.09K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 167.18K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 262.00K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 122.88K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 145.46K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 170.54K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 128.46K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 153.37K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 260.73K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 107.52K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 123.04K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 168.74K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 119.03K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 152.87K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 261.64K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 107.21K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 111.18K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 167.17K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 118.94K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 152.32K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 262.18K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 110.44K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 108.30K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 167.05K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 134.97K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 159.51K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 291.35K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 135.71K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 177.35K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 155.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 159.88K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 309.65K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 142.56K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 150.13K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 176.11K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 218.97K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 210.56K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 333.35K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 213.65K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 223.42K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 208.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 150.15K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 240.71K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 230.40K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.31K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 122.71K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 249.98K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 129.37K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 186.41K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 225.09K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 104.05K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.83K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 205.96K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 124.19K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 226.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 204.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 113.06K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.08K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 257.55K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 154.39K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 195.61K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 192.24K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 116.83K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 141.91K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 196.74K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 143.44K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 160.87K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 208.78K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 155.79K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 145.20K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 179.45K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 142.31K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 158.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 206.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 164.18K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 137.11K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 177.17K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 138.14K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 165.63K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 206.14K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 154.88K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.44K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 196.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 119.38K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 158.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 205.92K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 123.18K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 118.55K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 206.60K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 105.76K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 165.52K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 216.96K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 120.32K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 243.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 111.30K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 181.09K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 231.01K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 120.68K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 127.51K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 215.77K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 113.77K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 177.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 223.06K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 110.10K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.91K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 203.74K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 113.35K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 181.73K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 221.36K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 103.19K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 117.03K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 198.42K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 114.79K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 181.64K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 216.89K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 113.91K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 126.48K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 181.82K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 100.21K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 172.65K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 218.31K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 102.52K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 128.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 178.85K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 105.68K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 170.77K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 208.62K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 114.12K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 119.16K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 193.25K  --.-KB/s    in 0s
# ...
# rawdata.oceanobserv 100%[===================>] 233.08K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 134.26K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 187.72K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 214.08K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 144.57K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 135.17K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 183.27K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 135.11K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 179.63K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 209.54K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 142.38K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 162.69K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 176.46K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 132.43K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 164.26K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 205.79K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 149.72K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 136.03K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 194.34K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 117.55K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 159.96K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 194.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 151.37K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.99K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 178.94K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 130.16K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 164.56K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 194.70K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.70K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 134.56K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 173.84K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 151.31K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 159.17K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 197.13K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 144.83K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 123.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 195.67K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.63K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 169.16K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 193.77K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 147.95K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 140.57K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 177.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 126.16K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 172.78K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 192.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 152.09K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 111.72K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 205.73K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 117.11K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 147.26K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 193.01K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 126.76K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 120.86K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 177.09K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 126.04K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 163.00K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 204.15K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 161.99K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 130.21K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 178.84K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 132.83K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 155.86K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 190.09K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 153.07K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 127.88K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 179.47K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 137.58K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 171.13K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 208.91K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.48K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 133.26K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 191.55K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 145.70K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 183.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 242.95K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 143.39K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.40K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 229.91K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 177.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 220.14K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 273.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 192.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 174.62K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 252.78K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 110.00K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 175.12K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 321.43K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 130.60K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 113.83K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 194.56K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv     [ <=>                ]  24.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 106.46K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 172.20K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 325.47K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 122.75K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 107.24K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 199.28K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 109.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 164.78K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 323.72K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 125.03K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 118.32K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 183.99K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 109.95K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 163.49K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 329.11K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.68K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 112.63K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 177.06K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 115.43K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 170.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 325.85K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 131.25K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 113.13K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 197.23K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 106.46K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 155.59K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 334.93K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 122.93K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 105.38K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 185.04K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 109.36K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 169.68K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 342.61K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 135.30K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 108.06K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 192.31K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 114.89K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 165.63K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 332.96K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 127.87K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 122.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 184.59K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 210.08K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 224.91K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 309.78K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 214.20K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 213.00K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 246.29K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 117.40K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 166.94K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 236.08K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 126.20K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 128.09K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 200.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 116.74K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 177.93K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 238.83K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 130.59K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 124.27K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 193.16K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>]  82.83K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 175.30K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 230.92K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.02K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 110.45K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 209.00K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 118.64K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 171.35K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 233.38K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.95K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 132.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 189.38K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 116.10K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 162.51K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 247.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 120.12K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 125.29K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 205.87K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 112.96K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 166.22K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 247.50K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 127.89K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 126.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 198.29K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 110.15K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 180.31K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 226.06K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 124.29K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 134.78K  --.-KB/s    in 0.001s
# rawdata.oceanobserv 100%[===================>] 186.02K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 127.80K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 158.26K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 227.08K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 106.29K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 121.94K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 198.89K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 116.71K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 169.32K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 239.10K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 125.20K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 129.63K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 191.18K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 112.33K  --.-KB/s    in 0s
# rawdata.oceanobserv 100%[===================>] 177.20K  --.-KB/s    in 0s
#           rawdata.o   0%[                    ]       0  --.-KB/s

# %% [markdown]
# ### Moving Data

# %%
# We're going to move all the images to a single directory for ease

raw_path = Path("./raw_data/rawdata.oceanobservatories.org/files/GI01SUMO")
log_file = Path("./relocation_log.txt")
halo_images_filtered = Path("./image_data/halo_filtered")
halo_images = Path("./image_data/halo_cam_2")

# make the dir if it doesn't exist
halo_images_filtered.mkdir(parents=True, exist_ok=True)
halo_images.mkdir(parents=True, exist_ok=True)

# start logging
with open(log_file, "a") as log:
    # make a list to filter images
    halo_cam_filters = ("cam61A0399F.jpg", "cam37C1DD9F.jpg", ".cam2.jpg")
    # walk-thru all directories and pull the .jpgs
    for root, dirs, files in os.walk(raw_path):
        for file in files:
            if file.lower().endswith(".jpg"):
                # Catching cam2 photos and filtering them out (these look at the halo and aren't really useful...)
                if any(filter in file for filter in halo_cam_filters):
                    
                    src_file = Path(root) / file
                    dst_file = halo_images / file
                    
                    # catch-all for potential naming duplicates
                    catcher = 1
                    while dst_file.exists():
                        dst_file = halo_images_filtered / f"{src_file.stem}_{catcher}{src_file.suffix}"
                        catcher += 1
        
                    # move the file
                    shutil.move(str(src_file), str(dst_file))
        
                    # generate a log file
                    log.write(f"Moved: {src_file} -> {dst_file}\n")
                # the remaining cam photos
                else:
                    src_file = Path(root) / file
                    dst_file = halo_images_filtered / file
        
                    # catch-all for potential naming duplicates
                    catcher = 1
                    while dst_file.exists():
                        dst_file = halo_images_filtered / f"{src_file.stem}_{catcher}{src_file.suffix}"
                        catcher += 1
        
                    # move the file
                    shutil.move(str(src_file), str(dst_file))
        
                    # generate a log file
                    log.write(f"Moved: {src_file} -> {dst_file}\n")

# %% [markdown]
# ### Begin filtering by cruise schedule
# ## NOTE: This wasn't very useful in the image analysis but keeping in case we need to sort by datetime later

# %%
# With the halo cams removed we can use the cruise schedule to only include relevant time-frame images
from datetime import datetime
import pandas as pd
from pathlib import Path
import shutil

# images path
images_path = Path("./image_data/halo_filtered")
# destination path
cruise_filtered = Path("./image_data/cruise_filtered")
# make directory
cruise_filtered.mkdir(parents=True, exist_ok=True)

# set-up timeframes
timeframes = [
    ("20200808_121800", "20200904_170200"),
    ("20210803_160600", "20210826_080500"),
    ("20220620_200000", "20220716_083500"),
    ("20230828_100000", "20230921_120800"),
    ("20240602_160200", "20240702_085000")
]

# toos files into a list
files = list(images_path.glob("*.jpg"))

# make a dataframe
df = pd.DataFrame({'filename': [f.name for f in files]})
df['ts_str'] = df['filename'].str.slice(0,15) #take yymmdd_hhmmss to a new column
df['ts'] = pd.to_datetime(df['ts_str'], format = '%Y%m%d_%H%M%S') # convert to datetime object

# declare ranges from timeframes 
ranges = [
    (pd.to_datetime(s, format='%Y%m%d_%H%M%S'),
     pd.to_datetime(e, format='%Y%m%d_%H%M%S'))
    for s, e in timeframes
]

# initialize false matches
mask = pd.Series(False, index=df.index)
# iterate through timeframe and swap to true if they line up
for start, end in ranges:
    mask |= df['ts'].between(start, end)
# gather photos that align
filtered = df[mask].reset_index(drop=True)
# gather photos that don't align
nonmatch = df[~mask].reset_index(drop=True)

# move images that matched into filtered directory

for filename in filtered['filename']:
    src = images_path / filename
    dst = cruise_filtered / filename
    shutil.move(src, dst)
